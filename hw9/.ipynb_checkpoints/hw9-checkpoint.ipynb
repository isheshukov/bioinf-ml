# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
import random
from typing import List
from tqdm import tqdm_notebook
from scipy.spatial.distance import pdist, squareform
from scipy.spatial import cKDTree
from itertools import combinations

# %% [markdown]
# # (2) Реализуйте Монте-Карло поиск.

# %%
data = pd.read_csv("../data/tsp.csv", index_col=0, header=None).values

# %%
plt.figure(figsize=(8,8))
plt.plot(data, 'b.')
plt.show()

# %%
distances = squareform(pdist(data, metric='cityblock'))

# %%
def eval_path(path):
    s = 0
    for i in range(len(path)-1):
        s += distances[path[i], path[i+1]]
    return s

def random_path(distances):
    a = list(range(len(data)))
    np.random.shuffle(a)
        
    return data[a], eval_path(a)

# %%
min_path, min_dist = min((random_path(distances) for _ in tqdm_notebook(range(1_000_000))), key = lambda t: t[1])
# Out:
# HBox(children=(IntProgress(value=0, max=1000000), HTML(value='')))

# %%
def plot_path_l1(path):
    for i in range(len(path)-1):
        # (x1, y1) -> (x2, y1) -> (x2,y2)      
        plt.plot([path[i][0], path[i+1][0]], [path[i][1], path[i][1]], 'r-')
        plt.plot([path[i+1][0], path[i+1][0]], [path[i][1], path[i+1][1]], 'r-')
    
    plt.plot(path[0][0], path[0][1], 'go') # start
    plt.plot(path[-1][0], path[-1][1], 'bo') # end

# %%
plt.figure(figsize=(20,15))
plt.scatter(data[:,0], data[:,1])

plot_path_l1(min_path)
print(f"Minimal distance {min_dist}")
plt.show()
# Out:
# Minimal distance 27290.0

# %% [markdown]
# # (2) Реализуйте поиск случайным блужданием.

# %%
a = list(range(len(data)))
def random_walk():
    best_walk = None
    best_dist = np.inf
    for _ in tqdm_notebook(range(int(1_000_000))):
        l, r = np.random.randint(0, len(data), size=2)
        a[l], a[r] = a[r], a[l]
        
        s = eval_path(a)
        if s < best_dist:
            best_dist = s
            best_walk = a

    return data[best_walk], best_dist

# %%
best_walk, best_dist = random_walk()
# Out:
# HBox(children=(IntProgress(value=0, max=1000000), HTML(value='')))

# %%
plt.figure(figsize=(20,15))
plt.scatter(data[:,0], data[:,1])

plot_path_l1(best_walk)
print(f"Minimal distance {best_dist}")
plt.show()
# Out:
# Minimal distance 26620.0

# %% [markdown]
# # (4) Реализуйте Hill Climb.

# %%
def step(walk):
    # берем два случайных города, обращаем путь между ними
    a = list(range(len(walk)))
    np.random.shuffle(a)
    for i,j in combinations(a, 2):
        _walk=np.copy(walk)
        if i < j:
            _walk[i:j+1]=np.flip(_walk[i:j+1])
        else:
            _walk[:j]=np.flip(_walk[:j])
            _walk[i:]=np.flip(_walk[i:])

        if (_walk != walk).any():
            yield _walk

def hillclimb():
    
    best_walk = list(range(len(data)))
    best_dist = eval_path(best_walk)
    
    for _ in tqdm_notebook(range(1_000_000)):
        move_made = False
        
        for s in step(best_walk):        
            next_dist = eval_path(s)
            if next_dist < best_dist:
                best_walk = s
                best_dist = next_dist
                move_made = True
                break
            
        if not move_made:
            break
    
    return best_dist, best_walk

# %%
best_dist, best_walk = hillclimb()
# Out:
# HBox(children=(IntProgress(value=0, max=1000000), HTML(value='')))

# %%
plt.figure(figsize=(20,15))
plt.scatter(data[:,0], data[:,1])

plot_path_l1(data[best_walk])
print(f"Minimal distance {best_dist}")
plt.show()
# Out:
# Minimal distance 9365.0

# %% [markdown]
# # (6) Реализуйте отжиг (simulated annealing)

# %%
def annealing():
    def get_neighbour(s):
        return next(step(s))
    
    def P(old, new, temp):
        old_cost = np.float64(eval_path(old))
        new_cost = np.float64(eval_path(new))
        
        if new_cost < old_cost:
            return 1.0
        else:
            return np.exp((old_cost - new_cost) / temp)

    s = list(range(len(data)))
    t0 = 1000
    for k in tqdm_notebook(range(100000)):
        t = t0 / (k+1)
        s_new = get_neighbour(s)
        
        if P(s, s_new, t) >= np.random.uniform():
            s = s_new
            
    return eval_path(s), s

# %%
best_dist, best_walk = annealing()
# Out:
# HBox(children=(IntProgress(value=0, max=100000), HTML(value='')))

# %%
plt.figure(figsize=(20,15))
plt.scatter(data[:,0], data[:,1])

plot_path_l1(data[best_walk])
print(f"Minimal distance {best_dist}")
plt.show()
# Out:
# Minimal distance 9400.0
